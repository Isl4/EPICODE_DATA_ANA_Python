# %%
#first exercise/practice  
##Let's identify three tasks of any type

#case number 1: remote job data analyst
#1.go to google.com
#2.select upwork platform 
#3.check your profile and if your name is visible
#4.do search about data analyst job
#5.check if they are loyal and good fit for me
#6.if not loyal go back to step N.4,if its ok go to step N.7
#7.send your cv and request about the job offer

#case number 2: Hotel Bookings
#1.go to booking.com platform
#2.create a profile as hotel adiministrator 
#3.insert price and locations ,instrcutions
#4.receive the reservations
#5.create a profile on hotel's system to do the check-in
#6.if the client paid the deposit directly , sign as confirmed, if not go to the step 7
#7.if the client hasn't paid the deposit , sign as not confirmed and leave it as stand_by

#case number 3: learn Deutsch Language
#1.check the best institute for german language
#2.check if there is a website availabile,if so check info and price , if not go to step 3
#3.seek around about phone number , and go to step 4
#4.they have a phone, call them about the price and availability, if not go to step 5
#5. seek the location and go to them to ask about the info
#6. if everything , do the enrollment and pay the course fees. 
#7.thanks

# %%
#Second exercise/practice 
# we have 25 students , please merorise it as variabile, 
#then add 3 new students as a new variabile 

Students=25
print(Students)

New_students=3
print(Students+New_students)

Name= "Epicode"
print(Name)

X=10
X=X+2
X=X*3
print(X)

str1 = "Windows"
str2 = "Excel" 
str3 = "Powerpoint"
str4 = "Word"
print(len(str1))
print(len(str2))
print(len(str3))
print(len(str4))

#calculate the seconds in the a year (365 days)
Days_year=365
Hours_Day=24
miuntes_hour=60
seconds_in_miute=60

seconds_in_year=Days_year*Hours_Day*miuntes_hour*seconds_in_miute
print(seconds_in_year)



##my_string = "I am studying Python" 
# Change it so that all characters are uppercase (uppercase) 
# Change it so that all characters are lowercase (lowercase) 
# Replace the substring "Python" with the string "a lot" 
# Use the .strip() method; does it change anything? Why? 
# Use the .split() method to find all words (tokens)

my_string="Im studying Python"
print(my_string.upper())
print(my_string.lower())
print(my_string.replace("Python","a lot"))
print(my_string.strip())
print(my_string.split())
# Out:
# 25
# 28
# Epicode
# 36
# 7
# 5
# 10
# 4
# 31536000
# IM STUDYING PYTHON
# im studying python
# Im studying a lot
# Im studying Python
# ['Im', 'studying', 'Python']
